# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as date
import random
from sklearn.cluster import KMeans

# %%
genders = []
information = pd.read_csv("PSIM/500.csv")
# for val in information['Gender']:
#     if (val == 'Male'):
#         genders.append(1)
#     else:
#         genders.append(0)
# information['Gender'] = genders
information = information.drop(['Gender'], axis=1)
information = information.drop(['Index'], axis=1)
information.head()
# Out:
#    Height  Weight
# 0     174      96
# 1     189      87
# 2     185     110
# 3     195     104
# 4     149      61

# %%
f1 = information['Weight'].values
f2 = information['Height'].values
x = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, s=7)

# %%
kmeans5 = KMeans(n_clusters=6)
y_kmeans5 = kmeans5.fit_predict(x)
print(y_kmeans5)
# Out:
# [1 1 1 1 2 1 1 1 1 1 2 2 1 2 2 1 1 0 0 0 1 0 1 0 2 2 1 2 0 0 1 2 2 0 0 0 1
#  2 0 2 1 1 2 1 0 2 1 1 2 0 0 2 1 1 1 1 1 0 2 2 2 0 2 2 0 0 1 2 2 0 2 1 2 2
#  1 0 1 1 1 2 2 0 1 1 1 2 0 1 1 0 0 1 1 2 1 0 2 0 2 2 0 1 0 0 0 1 0 0 1 2 2
#  0 0 1 1 2 2 1 1 0 2 1 0 0 0 1 1 2 0 2 0 2 0 1 0 0 0 1 0 0 2 2 0 1 2 1 1 0
#  1 1 2 2 2 0 1 1 2 0 1 1 1 2 1 0 1 2 1 1 2 2 0 0 0 0 0 1 1 1 0 1 2 1 1 2 1
#  2 0 2 0 1 2 1 1 0 1 1 2 1 0 0 2 1 1 1 0 2 1 1 1 2 2 0 0 0 2 0 1 2 0 1 2 0
#  1 0 2 0 2 1 1 0 0 2 1 2 2 2 0 0 2 1 2 2 2 0 2 1 1 0 1 1 2 0 0 0 0 2 1 1 0
#  0 1 0 0 2 2 2 0 0 0 2 0 1 1 2 2 1 1 2 2 2 2 0 1 1 0 0 2 0 2 1 2 1 2 2 0 0
#  1 2 1 2 0 1 2 1 0 1 0 2 2 0 0 0 0 2 2 0 1 0 1 0 1 1 1 0 2 2 1 2 2 1 0 2 2
#  2 2 2 0 0 1 0 2 1 1 2 1 1 2 2 0 2 2 1 2 0 2 1 1 0 2 0 2 1 0 0 0 2 1 0 0 2
#  2 0 2 2 1 0 1 0 1 1 1 2 1 0 0 2 0 2 2 2 2 2 2 1 0 2 1 0 2 0 1 1 2 1 0 0 2
#  0 0 0 2 1 0 0 1 1 1 2 0 2 2 0 0 1 2 2 0 0 2 1 2 0 1 0 2 0 0 0 2 0 1 2 0 0
# ...

# %%
centerModel = kmeans5.cluster_centers_
kmeans5.cluster_centers_
# Out:
# array([[143.29761905, 168.82142857],
#        [105.62874251, 172.67065868],
#        [ 68.4       , 168.32727273]])

# %%
plt.scatter(centerModel[:,0], centerModel[:,1], alpha=0.5)
plt.show()

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x[:,0], x[:,1], c=y_kmeans5, cmap='rainbow', alpha=0.2)
plt.scatter(centerModel[:,0], centerModel[:,1], color='black', marker='P', alpha=1)
plt.show()
